# %% [markdown]
# # Uncertainty quantification using "DRIVE: Digital Retinal Images for Vessel Extraction"
#
# __author__: Yongchan Kwon
#
# This notebook is the implementation example for paper "Uncertainty quantification using Bayesian neural networks in classification: Application to biomedical segmentation", the special issue of Medical Image Analysis.
#
# The followings are based on the Walter de Back's amazing notebook https://gitlab.com/wdeback/dl-keras-tutorial/blob/master/notebooks/3-cnn-segment-retina-uncertainty.ipynb
#
# **Reference**
#
# - J.J. Staal, M.D. Abramoff, M. Niemeijer, M.A. Viergever, B. van Ginneken, "Ridge based vessel segmentation in color images of the retina", IEEE Transactions on Medical Imaging, 2004, vol. 23, pp. 501-509.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import os, glob
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
np.random.seed(20180621)

from skimage.external import tifffile # read tiff images
from skimage.io import imread # read gif images
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras import backend as K
import seaborn as sns

from model import *
import utils
import time

plt.style.use('ggplot')
# Out:
# Using TensorFlow backend.

# %%
print('Backend: ', K.backend())
print('Image_data_format: ', K.image_data_format())
N_train = 200
# Out:
# Backend:  tensorflow
# Image_data_format:  channels_last

# %%
# load training images
fns = sorted(glob.glob('./input/training/images/*.tif'))
x_train = np.array([tifffile.imread(fn) for fn in fns])

# load test images
fns = sorted(glob.glob('./input/test/images/*.tif'))
x_test = np.array([tifffile.imread(fn) for fn in fns])
print('shape of raw train data: ', x_train.shape)
print('shape of raw test data: ',x_test.shape)
# Out:
# shape of raw train data:  (0,)
# shape of raw test data:  (0,)

# %%
 # load training annotations
fns = sorted(glob.glob('./input/training/1st_manual/*.gif'))
y_train = np.array([imread(fn) for fn in fns]) # read images
y_train = np.expand_dims(y_train, -1) # add channels dimension

# load test annotations
fns = sorted(glob.glob('./input/test/1st_manual/*.gif'))
y_test = np.array([imread(fn) for fn in fns]) # read images
y_test = np.expand_dims(y_test, -1) # add channels dimension
print('train shape:', y_train.shape)
print('test shape:', y_test.shape)
# Out:
# train shape: (20, 584, 565, 1)
# test shape: (20, 584, 565, 1)

# %% [markdown]
# ## Preprecossing

# %%
x_train = utils.preprocess(x_train)
x_test = utils.preprocess(x_test)

y_train = utils.preprocess(y_train)
y_test = utils.preprocess(y_test)
# Out:
# min: 0.0, max: 1.0, shape: (20, 584, 565, 3), type: float32
# min: 0.0, max: 1.0, shape: (20, 584, 565, 3), type: float32
# min: 0.0, max: 1.0, shape: (20, 584, 565, 1), type: float32
# min: 0.0, max: 1.0, shape: (20, 584, 565, 1), type: float32

# %%
X_train, Y_train = utils.get_random_snippets(x_train, y_train, number=N_train, size=(96,96))
X_test, Y_test = utils.get_random_snippets(x_test, y_test, number=1000, size=(96,96))

print('X_train shape: ', X_train.shape)
print('Y_train shape: ', Y_train.shape)
print('X_test shape: ', X_test.shape)
print('Y_test shape: ', Y_test.shape)
# Out:
# X_train shape:  (200, 96, 96, 3)
# Y_train shape:  (200, 96, 96, 1)
# X_test shape:  (1000, 96, 96, 3)
# Y_test shape:  (1000, 96, 96, 1)

# %%
plt.rcParams['figure.figsize'] = [15, 5]
M=6
list_index = np.random.randint(low=0, high=X_train.shape[0], size=M)
plt.figure(figsize=(20,20))
fig, ax = plt.subplots(2,M)
for k, ind in enumerate(list_index):
    ax[0,k].imshow(X_train[ind])
    ax[1,k].imshow(Y_train[ind,:,:,0], cmap='gray')
    
    ax[0,k].axis('off')
    ax[1,k].axis('off')

fig.savefig('./fig/DRIVE_example_200')

# %%
model = UNet(N_filters=16)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['binary_accuracy', dice_coefficient, precision_smooth, recall_smooth])
print("Number of parameters: ", model.count_params())
# Out:
# Number of parameters:  1115265

# %%
batch_size = 32
epochs = 200
info_check_string='./weights/DRIVE_stochastic_sample_200.hdf5'
early_stopping=EarlyStopping(monitor='val_loss', patience=10)
model_checkpoint=ModelCheckpoint(info_check_string, monitor='loss', save_best_only=True)

# %%
history = model.fit(X_train, Y_train,
                      batch_size=batch_size,
                      epochs=epochs,
                      shuffle=True,
                      verbose=1,
                      validation_split=0.2, # 4 samples are used for a validation set
                      callbacks=[early_stopping, model_checkpoint])
# Out:
# Train on 160 samples, validate on 40 samples
# Epoch 1/200
# 160/160 [==============================] - 8s 47ms/step - loss: 0.8637 - binary_accuracy: 0.5144 - dice_coefficient: 0.1920 - precision_smooth: 0.1182 - recall_smooth: 0.5144 - val_loss: 1.0152 - val_binary_accuracy: 0.5498 - val_dice_coefficient: 0.1801 - val_precision_smooth: 0.1092 - val_recall_smooth: 0.5184
# Epoch 2/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.7672 - binary_accuracy: 0.5296 - dice_coefficient: 0.2024 - precision_smooth: 0.1246 - recall_smooth: 0.5389 - val_loss: 0.6771 - val_binary_accuracy: 0.6773 - val_dice_coefficient: 0.1743 - val_precision_smooth: 0.1115 - val_recall_smooth: 0.4032
# Epoch 3/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.7358 - binary_accuracy: 0.5409 - dice_coefficient: 0.2069 - precision_smooth: 0.1277 - recall_smooth: 0.5464 - val_loss: 0.6660 - val_binary_accuracy: 0.6787 - val_dice_coefficient: 0.1832 - val_precision_smooth: 0.1164 - val_recall_smooth: 0.4332
# Epoch 4/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.7110 - binary_accuracy: 0.5662 - dice_coefficient: 0.2126 - precision_smooth: 0.1319 - recall_smooth: 0.5549 - val_loss: 0.7496 - val_binary_accuracy: 0.6508 - val_dice_coefficient: 0.1934 - val_precision_smooth: 0.1203 - val_recall_smooth: 0.4965
# Epoch 5/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.6876 - binary_accuracy: 0.6003 - dice_coefficient: 0.2288 - precision_smooth: 0.1420 - recall_smooth: 0.5887 - val_loss: 0.6733 - val_binary_accuracy: 0.6547 - val_dice_coefficient: 0.2034 - val_precision_smooth: 0.1260 - val_recall_smooth: 0.5309
# Epoch 6/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.6566 - binary_accuracy: 0.6322 - dice_coefficient: 0.2458 - precision_smooth: 0.1534 - recall_smooth: 0.6242 - val_loss: 2.1121 - val_binary_accuracy: 0.3612 - val_dice_coefficient: 0.2122 - val_precision_smooth: 0.1212 - val_recall_smooth: 0.8558
# Epoch 7/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.6274 - binary_accuracy: 0.6702 - dice_coefficient: 0.2653 - precision_smooth: 0.1661 - recall_smooth: 0.6613 - val_loss: 1.8682 - val_binary_accuracy: 0.3669 - val_dice_coefficient: 0.2153 - val_precision_smooth: 0.1232 - val_recall_smooth: 0.8581
# Epoch 8/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.6011 - binary_accuracy: 0.7022 - dice_coefficient: 0.2866 - precision_smooth: 0.1805 - recall_smooth: 0.6989 - val_loss: 0.9287 - val_binary_accuracy: 0.4733 - val_dice_coefficient: 0.2266 - val_precision_smooth: 0.1336 - val_recall_smooth: 0.7505
# Epoch 9/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.5762 - binary_accuracy: 0.7297 - dice_coefficient: 0.2955 - precision_smooth: 0.1873 - recall_smooth: 0.7064 - val_loss: 0.6179 - val_binary_accuracy: 0.6918 - val_dice_coefficient: 0.2270 - val_precision_smooth: 0.1409 - val_recall_smooth: 0.5883
# Epoch 10/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.5451 - binary_accuracy: 0.7598 - dice_coefficient: 0.3084 - precision_smooth: 0.1966 - recall_smooth: 0.7200 - val_loss: 0.8025 - val_binary_accuracy: 0.5519 - val_dice_coefficient: 0.2282 - val_precision_smooth: 0.1365 - val_recall_smooth: 0.7002
# Epoch 11/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.5198 - binary_accuracy: 0.7878 - dice_coefficient: 0.3245 - precision_smooth: 0.2087 - recall_smooth: 0.7357 - val_loss: 0.9871 - val_binary_accuracy: 0.5505 - val_dice_coefficient: 0.2569 - val_precision_smooth: 0.1521 - val_recall_smooth: 0.8292
# Epoch 12/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.4988 - binary_accuracy: 0.8108 - dice_coefficient: 0.3427 - precision_smooth: 0.2223 - recall_smooth: 0.7622 - val_loss: 0.4859 - val_binary_accuracy: 0.8361 - val_dice_coefficient: 0.3199 - val_precision_smooth: 0.2062 - val_recall_smooth: 0.7177
# Epoch 13/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.4702 - binary_accuracy: 0.8300 - dice_coefficient: 0.3463 - precision_smooth: 0.2253 - recall_smooth: 0.7539 - val_loss: 0.6519 - val_binary_accuracy: 0.7396 - val_dice_coefficient: 0.2806 - val_precision_smooth: 0.1742 - val_recall_smooth: 0.7256
# Epoch 14/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.4495 - binary_accuracy: 0.8460 - dice_coefficient: 0.3553 - precision_smooth: 0.2326 - recall_smooth: 0.7542 - val_loss: 0.4332 - val_binary_accuracy: 0.8667 - val_dice_coefficient: 0.3210 - val_precision_smooth: 0.2095 - val_recall_smooth: 0.6906
# Epoch 15/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.4316 - binary_accuracy: 0.8641 - dice_coefficient: 0.3697 - precision_smooth: 0.2440 - recall_smooth: 0.7659 - val_loss: 0.4480 - val_binary_accuracy: 0.8525 - val_dice_coefficient: 0.3140 - val_precision_smooth: 0.2055 - val_recall_smooth: 0.6691
# Epoch 16/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.4144 - binary_accuracy: 0.8751 - dice_coefficient: 0.3769 - precision_smooth: 0.2499 - recall_smooth: 0.7671 - val_loss: 0.3317 - val_binary_accuracy: 0.9151 - val_dice_coefficient: 0.3523 - val_precision_smooth: 0.2465 - val_recall_smooth: 0.6206
# Epoch 17/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.4046 - binary_accuracy: 0.8826 - dice_coefficient: 0.3820 - precision_smooth: 0.2554 - recall_smooth: 0.7659 - val_loss: 0.3562 - val_binary_accuracy: 0.8983 - val_dice_coefficient: 0.3087 - val_precision_smooth: 0.2129 - val_recall_smooth: 0.5647
# Epoch 18/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.3913 - binary_accuracy: 0.8900 - dice_coefficient: 0.3887 - precision_smooth: 0.2611 - recall_smooth: 0.7664 - val_loss: 0.3171 - val_binary_accuracy: 0.9181 - val_dice_coefficient: 0.3402 - val_precision_smooth: 0.2418 - val_recall_smooth: 0.5776
# Epoch 19/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3788 - binary_accuracy: 0.8994 - dice_coefficient: 0.3964 - precision_smooth: 0.2677 - recall_smooth: 0.7697 - val_loss: 0.2972 - val_binary_accuracy: 0.9174 - val_dice_coefficient: 0.2718 - val_precision_smooth: 0.2072 - val_recall_smooth: 0.3980
# Epoch 20/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.3697 - binary_accuracy: 0.9030 - dice_coefficient: 0.4047 - precision_smooth: 0.2754 - recall_smooth: 0.7730 - val_loss: 0.2917 - val_binary_accuracy: 0.9264 - val_dice_coefficient: 0.3599 - val_precision_smooth: 0.2632 - val_recall_smooth: 0.5731
# Epoch 21/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3585 - binary_accuracy: 0.9088 - dice_coefficient: 0.4092 - precision_smooth: 0.2796 - recall_smooth: 0.7675 - val_loss: 0.2797 - val_binary_accuracy: 0.9295 - val_dice_coefficient: 0.3622 - val_precision_smooth: 0.2712 - val_recall_smooth: 0.5476
# Epoch 22/200
# 160/160 [==============================] - 1s 4ms/step - loss: 0.3491 - binary_accuracy: 0.9136 - dice_coefficient: 0.4097 - precision_smooth: 0.2818 - recall_smooth: 0.7590 - val_loss: 0.2798 - val_binary_accuracy: 0.9276 - val_dice_coefficient: 0.3493 - val_precision_smooth: 0.2631 - val_recall_smooth: 0.5223
# Epoch 23/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.3393 - binary_accuracy: 0.9174 - dice_coefficient: 0.4241 - precision_smooth: 0.2932 - recall_smooth: 0.7708 - val_loss: 0.2586 - val_binary_accuracy: 0.9371 - val_dice_coefficient: 0.3996 - val_precision_smooth: 0.3033 - val_recall_smooth: 0.5881
# Epoch 24/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.3285 - binary_accuracy: 0.9226 - dice_coefficient: 0.4251 - precision_smooth: 0.2952 - recall_smooth: 0.7599 - val_loss: 0.2577 - val_binary_accuracy: 0.9345 - val_dice_coefficient: 0.3804 - val_precision_smooth: 0.2927 - val_recall_smooth: 0.5444
# Epoch 25/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3226 - binary_accuracy: 0.9236 - dice_coefficient: 0.4319 - precision_smooth: 0.3028 - recall_smooth: 0.7613 - val_loss: 0.2569 - val_binary_accuracy: 0.9382 - val_dice_coefficient: 0.4187 - val_precision_smooth: 0.3153 - val_recall_smooth: 0.6255
# Epoch 26/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.3119 - binary_accuracy: 0.9266 - dice_coefficient: 0.4405 - precision_smooth: 0.3101 - recall_smooth: 0.7633 - val_loss: 0.2464 - val_binary_accuracy: 0.9394 - val_dice_coefficient: 0.4179 - val_precision_smooth: 0.3222 - val_recall_smooth: 0.5964
# Epoch 27/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.3037 - binary_accuracy: 0.9298 - dice_coefficient: 0.4518 - precision_smooth: 0.3207 - recall_smooth: 0.7685 - val_loss: 0.2620 - val_binary_accuracy: 0.9334 - val_dice_coefficient: 0.4010 - val_precision_smooth: 0.3152 - val_recall_smooth: 0.5530
# Epoch 28/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2996 - binary_accuracy: 0.9304 - dice_coefficient: 0.4448 - precision_smooth: 0.3177 - recall_smooth: 0.7486 - val_loss: 0.2422 - val_binary_accuracy: 0.9401 - val_dice_coefficient: 0.4316 - val_precision_smooth: 0.3350 - val_recall_smooth: 0.6096
# Epoch 29/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2897 - binary_accuracy: 0.9340 - dice_coefficient: 0.4607 - precision_smooth: 0.3307 - recall_smooth: 0.7625 - val_loss: 0.2586 - val_binary_accuracy: 0.9344 - val_dice_coefficient: 0.3699 - val_precision_smooth: 0.2817 - val_recall_smooth: 0.5412
# Epoch 30/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2810 - binary_accuracy: 0.9363 - dice_coefficient: 0.4681 - precision_smooth: 0.3382 - recall_smooth: 0.7614 - val_loss: 0.2622 - val_binary_accuracy: 0.9338 - val_dice_coefficient: 0.4109 - val_precision_smooth: 0.3132 - val_recall_smooth: 0.5995
# Epoch 31/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2726 - binary_accuracy: 0.9374 - dice_coefficient: 0.4696 - precision_smooth: 0.3415 - recall_smooth: 0.7527 - val_loss: 0.2607 - val_binary_accuracy: 0.9401 - val_dice_coefficient: 0.4555 - val_precision_smooth: 0.3411 - val_recall_smooth: 0.6878
# Epoch 32/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2637 - binary_accuracy: 0.9402 - dice_coefficient: 0.4887 - precision_smooth: 0.3582 - recall_smooth: 0.7718 - val_loss: 0.2280 - val_binary_accuracy: 0.9402 - val_dice_coefficient: 0.4309 - val_precision_smooth: 0.3488 - val_recall_smooth: 0.5663
# Epoch 33/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2597 - binary_accuracy: 0.9414 - dice_coefficient: 0.4856 - precision_smooth: 0.3582 - recall_smooth: 0.7571 - val_loss: 0.2306 - val_binary_accuracy: 0.9363 - val_dice_coefficient: 0.4126 - val_precision_smooth: 0.3525 - val_recall_smooth: 0.4996
# Epoch 34/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2539 - binary_accuracy: 0.9423 - dice_coefficient: 0.4911 - precision_smooth: 0.3656 - recall_smooth: 0.7525 - val_loss: 0.2178 - val_binary_accuracy: 0.9387 - val_dice_coefficient: 0.4302 - val_precision_smooth: 0.3666 - val_recall_smooth: 0.5232
# Epoch 35/200
# 160/160 [==============================] - 1s 4ms/step - loss: 0.2468 - binary_accuracy: 0.9433 - dice_coefficient: 0.5061 - precision_smooth: 0.3785 - recall_smooth: 0.7649 - val_loss: 0.2234 - val_binary_accuracy: 0.9430 - val_dice_coefficient: 0.4789 - val_precision_smooth: 0.3868 - val_recall_smooth: 0.6303
# Epoch 36/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2439 - binary_accuracy: 0.9434 - dice_coefficient: 0.5080 - precision_smooth: 0.3837 - recall_smooth: 0.7626 - val_loss: 0.2202 - val_binary_accuracy: 0.9389 - val_dice_coefficient: 0.4425 - val_precision_smooth: 0.3759 - val_recall_smooth: 0.5403
# Epoch 37/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2395 - binary_accuracy: 0.9445 - dice_coefficient: 0.5026 - precision_smooth: 0.3815 - recall_smooth: 0.7463 - val_loss: 0.2080 - val_binary_accuracy: 0.9424 - val_dice_coefficient: 0.4660 - val_precision_smooth: 0.3988 - val_recall_smooth: 0.5627
# Epoch 38/200
# 160/160 [==============================] - 1s 4ms/step - loss: 0.2334 - binary_accuracy: 0.9455 - dice_coefficient: 0.5157 - precision_smooth: 0.3934 - recall_smooth: 0.7535 - val_loss: 0.2255 - val_binary_accuracy: 0.9319 - val_dice_coefficient: 0.3869 - val_precision_smooth: 0.3642 - val_recall_smooth: 0.4153
# Epoch 39/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2288 - binary_accuracy: 0.9456 - dice_coefficient: 0.5229 - precision_smooth: 0.4023 - recall_smooth: 0.7563 - val_loss: 0.2038 - val_binary_accuracy: 0.9410 - val_dice_coefficient: 0.4744 - val_precision_smooth: 0.4201 - val_recall_smooth: 0.5462
# Epoch 40/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2259 - binary_accuracy: 0.9468 - dice_coefficient: 0.5215 - precision_smooth: 0.4030 - recall_smooth: 0.7459 - val_loss: 0.2194 - val_binary_accuracy: 0.9338 - val_dice_coefficient: 0.4154 - val_precision_smooth: 0.3996 - val_recall_smooth: 0.4342
# Epoch 41/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2206 - binary_accuracy: 0.9473 - dice_coefficient: 0.5333 - precision_smooth: 0.4146 - recall_smooth: 0.7503 - val_loss: 0.2121 - val_binary_accuracy: 0.9369 - val_dice_coefficient: 0.4252 - val_precision_smooth: 0.3846 - val_recall_smooth: 0.4777
# Epoch 42/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2184 - binary_accuracy: 0.9468 - dice_coefficient: 0.5397 - precision_smooth: 0.4221 - recall_smooth: 0.7555 - val_loss: 0.2055 - val_binary_accuracy: 0.9405 - val_dice_coefficient: 0.4879 - val_precision_smooth: 0.4562 - val_recall_smooth: 0.5258
# Epoch 43/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2088 - binary_accuracy: 0.9491 - dice_coefficient: 0.5464 - precision_smooth: 0.4296 - recall_smooth: 0.7522 - val_loss: 0.2161 - val_binary_accuracy: 0.9336 - val_dice_coefficient: 0.4198 - val_precision_smooth: 0.4267 - val_recall_smooth: 0.4150
# Epoch 44/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2069 - binary_accuracy: 0.9489 - dice_coefficient: 0.5543 - precision_smooth: 0.4390 - recall_smooth: 0.7557 - val_loss: 0.1825 - val_binary_accuracy: 0.9468 - val_dice_coefficient: 0.5243 - val_precision_smooth: 0.4732 - val_recall_smooth: 0.5887
# Epoch 45/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2058 - binary_accuracy: 0.9488 - dice_coefficient: 0.5488 - precision_smooth: 0.4377 - recall_smooth: 0.7461 - val_loss: 0.1922 - val_binary_accuracy: 0.9415 - val_dice_coefficient: 0.4862 - val_precision_smooth: 0.4663 - val_recall_smooth: 0.5096
# Epoch 46/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2019 - binary_accuracy: 0.9495 - dice_coefficient: 0.5579 - precision_smooth: 0.4479 - recall_smooth: 0.7463 - val_loss: 0.1916 - val_binary_accuracy: 0.9417 - val_dice_coefficient: 0.4946 - val_precision_smooth: 0.4723 - val_recall_smooth: 0.5211
# Epoch 47/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1939 - binary_accuracy: 0.9514 - dice_coefficient: 0.5665 - precision_smooth: 0.4556 - recall_smooth: 0.7513 - val_loss: 0.1926 - val_binary_accuracy: 0.9413 - val_dice_coefficient: 0.4961 - val_precision_smooth: 0.4801 - val_recall_smooth: 0.5150
# Epoch 48/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1928 - binary_accuracy: 0.9507 - dice_coefficient: 0.5701 - precision_smooth: 0.4627 - recall_smooth: 0.7515 - val_loss: 0.1980 - val_binary_accuracy: 0.9384 - val_dice_coefficient: 0.4711 - val_precision_smooth: 0.4625 - val_recall_smooth: 0.4820
# Epoch 49/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1891 - binary_accuracy: 0.9511 - dice_coefficient: 0.5835 - precision_smooth: 0.4745 - recall_smooth: 0.7617 - val_loss: 0.2200 - val_binary_accuracy: 0.9302 - val_dice_coefficient: 0.4103 - val_precision_smooth: 0.4575 - val_recall_smooth: 0.3738
# Epoch 50/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1860 - binary_accuracy: 0.9519 - dice_coefficient: 0.5805 - precision_smooth: 0.4753 - recall_smooth: 0.7490 - val_loss: 0.1952 - val_binary_accuracy: 0.9395 - val_dice_coefficient: 0.4974 - val_precision_smooth: 0.5219 - val_recall_smooth: 0.4760
# Epoch 51/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1842 - binary_accuracy: 0.9520 - dice_coefficient: 0.5803 - precision_smooth: 0.4777 - recall_smooth: 0.7445 - val_loss: 0.1908 - val_binary_accuracy: 0.9409 - val_dice_coefficient: 0.5021 - val_precision_smooth: 0.5048 - val_recall_smooth: 0.5011
# Epoch 52/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1789 - binary_accuracy: 0.9530 - dice_coefficient: 0.5957 - precision_smooth: 0.4923 - recall_smooth: 0.7563 - val_loss: 0.1749 - val_binary_accuracy: 0.9470 - val_dice_coefficient: 0.5521 - val_precision_smooth: 0.5319 - val_recall_smooth: 0.5745
# Epoch 53/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1786 - binary_accuracy: 0.9528 - dice_coefficient: 0.5923 - precision_smooth: 0.4922 - recall_smooth: 0.7534 - val_loss: 0.1792 - val_binary_accuracy: 0.9440 - val_dice_coefficient: 0.5359 - val_precision_smooth: 0.5395 - val_recall_smooth: 0.5339
# Epoch 54/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1735 - binary_accuracy: 0.9537 - dice_coefficient: 0.6062 - precision_smooth: 0.5053 - recall_smooth: 0.7594 - val_loss: 0.1778 - val_binary_accuracy: 0.9447 - val_dice_coefficient: 0.5401 - val_precision_smooth: 0.5442 - val_recall_smooth: 0.5372
# Epoch 55/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1720 - binary_accuracy: 0.9541 - dice_coefficient: 0.6034 - precision_smooth: 0.5054 - recall_smooth: 0.7511 - val_loss: 0.1752 - val_binary_accuracy: 0.9465 - val_dice_coefficient: 0.5561 - val_precision_smooth: 0.5453 - val_recall_smooth: 0.5681
# Epoch 56/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1696 - binary_accuracy: 0.9538 - dice_coefficient: 0.6115 - precision_smooth: 0.5143 - recall_smooth: 0.7563 - val_loss: 0.1731 - val_binary_accuracy: 0.9460 - val_dice_coefficient: 0.5593 - val_precision_smooth: 0.5602 - val_recall_smooth: 0.5595
# Epoch 57/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1668 - binary_accuracy: 0.9543 - dice_coefficient: 0.6202 - precision_smooth: 0.5233 - recall_smooth: 0.7624 - val_loss: 0.1816 - val_binary_accuracy: 0.9416 - val_dice_coefficient: 0.5212 - val_precision_smooth: 0.5497 - val_recall_smooth: 0.4972
# Epoch 58/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1672 - binary_accuracy: 0.9539 - dice_coefficient: 0.6098 - precision_smooth: 0.5166 - recall_smooth: 0.7480 - val_loss: 0.1696 - val_binary_accuracy: 0.9471 - val_dice_coefficient: 0.5693 - val_precision_smooth: 0.5652 - val_recall_smooth: 0.5742
# Epoch 59/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1646 - binary_accuracy: 0.9544 - dice_coefficient: 0.6144 - precision_smooth: 0.5245 - recall_smooth: 0.7477 - val_loss: 0.1850 - val_binary_accuracy: 0.9417 - val_dice_coefficient: 0.5254 - val_precision_smooth: 0.5645 - val_recall_smooth: 0.4921
# Epoch 60/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1624 - binary_accuracy: 0.9547 - dice_coefficient: 0.6231 - precision_smooth: 0.5334 - recall_smooth: 0.7535 - val_loss: 0.1746 - val_binary_accuracy: 0.9458 - val_dice_coefficient: 0.5678 - val_precision_smooth: 0.5836 - val_recall_smooth: 0.5539
# Epoch 61/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1594 - binary_accuracy: 0.9552 - dice_coefficient: 0.6307 - precision_smooth: 0.5400 - recall_smooth: 0.7602 - val_loss: 0.1660 - val_binary_accuracy: 0.9474 - val_dice_coefficient: 0.5779 - val_precision_smooth: 0.6009 - val_recall_smooth: 0.5570
# Epoch 62/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1565 - binary_accuracy: 0.9555 - dice_coefficient: 0.6342 - precision_smooth: 0.5443 - recall_smooth: 0.7617 - val_loss: 0.1670 - val_binary_accuracy: 0.9464 - val_dice_coefficient: 0.5722 - val_precision_smooth: 0.6043 - val_recall_smooth: 0.5441
# Epoch 63/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1544 - binary_accuracy: 0.9560 - dice_coefficient: 0.6352 - precision_smooth: 0.5487 - recall_smooth: 0.7559 - val_loss: 0.1744 - val_binary_accuracy: 0.9442 - val_dice_coefficient: 0.5560 - val_precision_smooth: 0.5908 - val_recall_smooth: 0.5259
# Epoch 64/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1527 - binary_accuracy: 0.9563 - dice_coefficient: 0.6405 - precision_smooth: 0.5544 - recall_smooth: 0.7585 - val_loss: 0.1637 - val_binary_accuracy: 0.9483 - val_dice_coefficient: 0.5942 - val_precision_smooth: 0.6064 - val_recall_smooth: 0.5830
# Epoch 65/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1534 - binary_accuracy: 0.9557 - dice_coefficient: 0.6412 - precision_smooth: 0.5567 - recall_smooth: 0.7618 - val_loss: 0.1747 - val_binary_accuracy: 0.9444 - val_dice_coefficient: 0.5591 - val_precision_smooth: 0.6026 - val_recall_smooth: 0.5228
# Epoch 66/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1505 - binary_accuracy: 0.9565 - dice_coefficient: 0.6431 - precision_smooth: 0.5608 - recall_smooth: 0.7554 - val_loss: 0.1671 - val_binary_accuracy: 0.9476 - val_dice_coefficient: 0.5801 - val_precision_smooth: 0.5971 - val_recall_smooth: 0.5644
# Epoch 67/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1510 - binary_accuracy: 0.9562 - dice_coefficient: 0.6416 - precision_smooth: 0.5618 - recall_smooth: 0.7542 - val_loss: 0.1663 - val_binary_accuracy: 0.9468 - val_dice_coefficient: 0.5766 - val_precision_smooth: 0.5968 - val_recall_smooth: 0.5585
# Epoch 68/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1470 - binary_accuracy: 0.9572 - dice_coefficient: 0.6578 - precision_smooth: 0.5759 - recall_smooth: 0.7680 - val_loss: 0.1599 - val_binary_accuracy: 0.9480 - val_dice_coefficient: 0.5878 - val_precision_smooth: 0.6077 - val_recall_smooth: 0.5697
# Epoch 69/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1456 - binary_accuracy: 0.9573 - dice_coefficient: 0.6592 - precision_smooth: 0.5782 - recall_smooth: 0.7677 - val_loss: 0.1645 - val_binary_accuracy: 0.9484 - val_dice_coefficient: 0.6034 - val_precision_smooth: 0.6332 - val_recall_smooth: 0.5768
# Epoch 70/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1459 - binary_accuracy: 0.9566 - dice_coefficient: 0.6516 - precision_smooth: 0.5740 - recall_smooth: 0.7578 - val_loss: 0.1729 - val_binary_accuracy: 0.9431 - val_dice_coefficient: 0.5517 - val_precision_smooth: 0.5945 - val_recall_smooth: 0.5160
# Epoch 71/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1425 - binary_accuracy: 0.9577 - dice_coefficient: 0.6611 - precision_smooth: 0.5851 - recall_smooth: 0.7601 - val_loss: 0.1606 - val_binary_accuracy: 0.9492 - val_dice_coefficient: 0.6067 - val_precision_smooth: 0.6358 - val_recall_smooth: 0.5805
# Epoch 72/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1420 - binary_accuracy: 0.9572 - dice_coefficient: 0.6580 - precision_smooth: 0.5833 - recall_smooth: 0.7566 - val_loss: 0.1798 - val_binary_accuracy: 0.9406 - val_dice_coefficient: 0.5374 - val_precision_smooth: 0.6212 - val_recall_smooth: 0.4749
# Epoch 73/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1406 - binary_accuracy: 0.9576 - dice_coefficient: 0.6665 - precision_smooth: 0.5901 - recall_smooth: 0.7686 - val_loss: 0.1584 - val_binary_accuracy: 0.9493 - val_dice_coefficient: 0.6154 - val_precision_smooth: 0.6532 - val_recall_smooth: 0.5822
# Epoch 74/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1400 - binary_accuracy: 0.9574 - dice_coefficient: 0.6603 - precision_smooth: 0.5886 - recall_smooth: 0.7569 - val_loss: 0.1642 - val_binary_accuracy: 0.9478 - val_dice_coefficient: 0.6018 - val_precision_smooth: 0.6474 - val_recall_smooth: 0.5628
# Epoch 75/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1373 - binary_accuracy: 0.9581 - dice_coefficient: 0.6735 - precision_smooth: 0.6011 - recall_smooth: 0.7666 - val_loss: 0.1532 - val_binary_accuracy: 0.9511 - val_dice_coefficient: 0.6273 - val_precision_smooth: 0.6335 - val_recall_smooth: 0.6215
# Epoch 76/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1372 - binary_accuracy: 0.9581 - dice_coefficient: 0.6718 - precision_smooth: 0.5993 - recall_smooth: 0.7681 - val_loss: 0.1581 - val_binary_accuracy: 0.9498 - val_dice_coefficient: 0.6167 - val_precision_smooth: 0.6384 - val_recall_smooth: 0.5969
# Epoch 77/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1363 - binary_accuracy: 0.9583 - dice_coefficient: 0.6739 - precision_smooth: 0.6051 - recall_smooth: 0.7646 - val_loss: 0.1556 - val_binary_accuracy: 0.9501 - val_dice_coefficient: 0.6071 - val_precision_smooth: 0.6238 - val_recall_smooth: 0.5919
# Epoch 78/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1336 - binary_accuracy: 0.9588 - dice_coefficient: 0.6784 - precision_smooth: 0.6086 - recall_smooth: 0.7678 - val_loss: 0.1508 - val_binary_accuracy: 0.9510 - val_dice_coefficient: 0.6250 - val_precision_smooth: 0.6369 - val_recall_smooth: 0.6140
# Epoch 79/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1360 - binary_accuracy: 0.9579 - dice_coefficient: 0.6752 - precision_smooth: 0.6073 - recall_smooth: 0.7623 - val_loss: 0.1589 - val_binary_accuracy: 0.9488 - val_dice_coefficient: 0.6094 - val_precision_smooth: 0.6401 - val_recall_smooth: 0.5823
# Epoch 80/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1328 - binary_accuracy: 0.9584 - dice_coefficient: 0.6789 - precision_smooth: 0.6111 - recall_smooth: 0.7664 - val_loss: 0.1615 - val_binary_accuracy: 0.9481 - val_dice_coefficient: 0.6094 - val_precision_smooth: 0.6549 - val_recall_smooth: 0.5704
# Epoch 81/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1298 - binary_accuracy: 0.9593 - dice_coefficient: 0.6823 - precision_smooth: 0.6155 - recall_smooth: 0.7667 - val_loss: 0.1567 - val_binary_accuracy: 0.9497 - val_dice_coefficient: 0.6176 - val_precision_smooth: 0.6235 - val_recall_smooth: 0.6125
# Epoch 82/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1308 - binary_accuracy: 0.9587 - dice_coefficient: 0.6856 - precision_smooth: 0.6195 - recall_smooth: 0.7726 - val_loss: 0.1570 - val_binary_accuracy: 0.9487 - val_dice_coefficient: 0.6137 - val_precision_smooth: 0.6489 - val_recall_smooth: 0.5826
# Epoch 83/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1277 - binary_accuracy: 0.9598 - dice_coefficient: 0.6909 - precision_smooth: 0.6254 - recall_smooth: 0.7724 - val_loss: 0.1491 - val_binary_accuracy: 0.9518 - val_dice_coefficient: 0.6381 - val_precision_smooth: 0.6601 - val_recall_smooth: 0.6176
# Epoch 84/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1276 - binary_accuracy: 0.9599 - dice_coefficient: 0.6880 - precision_smooth: 0.6254 - recall_smooth: 0.7664 - val_loss: 0.1544 - val_binary_accuracy: 0.9505 - val_dice_coefficient: 0.6333 - val_precision_smooth: 0.6714 - val_recall_smooth: 0.5995
# Epoch 85/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1280 - binary_accuracy: 0.9594 - dice_coefficient: 0.6902 - precision_smooth: 0.6280 - recall_smooth: 0.7682 - val_loss: 0.1549 - val_binary_accuracy: 0.9503 - val_dice_coefficient: 0.6234 - val_precision_smooth: 0.6405 - val_recall_smooth: 0.6076
# Epoch 86/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1320 - binary_accuracy: 0.9579 - dice_coefficient: 0.6774 - precision_smooth: 0.6178 - recall_smooth: 0.7628 - val_loss: 0.1618 - val_binary_accuracy: 0.9494 - val_dice_coefficient: 0.6240 - val_precision_smooth: 0.6314 - val_recall_smooth: 0.6173
# Epoch 87/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1250 - binary_accuracy: 0.9600 - dice_coefficient: 0.6964 - precision_smooth: 0.6332 - recall_smooth: 0.7760 - val_loss: 0.1548 - val_binary_accuracy: 0.9512 - val_dice_coefficient: 0.6394 - val_precision_smooth: 0.6578 - val_recall_smooth: 0.6221
# Epoch 88/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1228 - binary_accuracy: 0.9604 - dice_coefficient: 0.6990 - precision_smooth: 0.6390 - recall_smooth: 0.7715 - val_loss: 0.1497 - val_binary_accuracy: 0.9522 - val_dice_coefficient: 0.6496 - val_precision_smooth: 0.6693 - val_recall_smooth: 0.6315
# Epoch 89/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1253 - binary_accuracy: 0.9595 - dice_coefficient: 0.6934 - precision_smooth: 0.6356 - recall_smooth: 0.7692 - val_loss: 0.1504 - val_binary_accuracy: 0.9509 - val_dice_coefficient: 0.6393 - val_precision_smooth: 0.6805 - val_recall_smooth: 0.6029
# Epoch 90/200
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1224 - binary_accuracy: 0.9604 - dice_coefficient: 0.7015 - precision_smooth: 0.6414 - recall_smooth: 0.7770 - val_loss: 0.1496 - val_binary_accuracy: 0.9518 - val_dice_coefficient: 0.6495 - val_precision_smooth: 0.6677 - val_recall_smooth: 0.6324
# Epoch 91/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1245 - binary_accuracy: 0.9597 - dice_coefficient: 0.7027 - precision_smooth: 0.6424 - recall_smooth: 0.7801 - val_loss: 0.1541 - val_binary_accuracy: 0.9507 - val_dice_coefficient: 0.6328 - val_precision_smooth: 0.6881 - val_recall_smooth: 0.5860
# Epoch 92/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1217 - binary_accuracy: 0.9604 - dice_coefficient: 0.6951 - precision_smooth: 0.6425 - recall_smooth: 0.7585 - val_loss: 0.1533 - val_binary_accuracy: 0.9524 - val_dice_coefficient: 0.6478 - val_precision_smooth: 0.6479 - val_recall_smooth: 0.6477
# Epoch 93/200
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1205 - binary_accuracy: 0.9607 - dice_coefficient: 0.7038 - precision_smooth: 0.6483 - recall_smooth: 0.7705 - val_loss: 0.1554 - val_binary_accuracy: 0.9529 - val_dice_coefficient: 0.6649 - val_precision_smooth: 0.6706 - val_recall_smooth: 0.6595

# %%
score = model.evaluate(X_test, Y_test, verbose=1)
print('Test loss, acc, dice, precision, recall):', score)
# Out:
# 1000/1000 [==============================] - 1s 1ms/step
# Test loss, acc, dice, precision, recall): [0.17214021468162535, 0.9460740017890931, 0.6654423041343689, 0.7034396347999573, 0.6318266978263855]

# %%
 def plot_history(history, validation=False):
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5,5), sharex=True)
    #fig.tight_layout()
    # plot history for loss
    ax.plot(history.history['loss'])
    if validation:
        ax.plot(history.history['val_loss'])
    ax.set_title('Loss')
    ax.set_ylabel('Loss')
    ax.set_ylim(bottom=0.)
    ax.set_xlabel('Epoch')
    ax.legend(['train', 'test'])
    
    plt.savefig('./fig/loss_curve_200')
    
plot_history(history, validation=True)

# %% [markdown]
# # Bayesian neural network: stochastic feed forward

# %%
# It takes a time !! 
num = len(X_test)
list_stochastic_feed_forwards = [3,5,10,15,20,30]
results = np.zeros((5, len(list_stochastic_feed_forwards)))
for ind, num_stochastic_T in enumerate(list_stochastic_feed_forwards):
    start = time.time()
    alea_mean = 0.
    epis_mean = 0.
    dice_mean = 0.
    for i in range(num):
        image = X_test[i]
        gt    = Y_test[i]
        prediction, aleatoric, epistemic, scores = utils.predict(model, image, gt, T=num_stochastic_T)
        alea_mean += np.mean(aleatoric) / num
        epis_mean += np.mean(epistemic) / num
        dice_mean += scores[0] / num
    
    end = time.time()
    print('T: ', num_stochastic_T)
    print('Exec time per prediction = {:.3f}'.format((end-start)/num))
    print('aleatoric: ', alea_mean)
    print('epistemic: ', epis_mean)    
    print('Dice: ', dice_mean)    
    
    results[0,ind]=num_stochastic_T
    results[1,ind]=(end-start)/num
    results[2,ind]=alea_mean
    results[3,ind]=epis_mean  
    results[4,ind]=dice_mean

print('-'*30)
print(results)    
print('-'*30)
# Out:
# T:  3
# Exec time per prediction = 0.042
# aleatoric:  0.028298671214841305
# epistemic:  0.003060231439987544
# Dice:  0.9460610892176617
# T:  5
# Exec time per prediction = 0.063
# aleatoric:  0.02828859902359547
# epistemic:  0.003678056659438885
# Dice:  0.9461218531131736
# T:  10
# Exec time per prediction = 0.109
# aleatoric:  0.028308511946350316
# epistemic:  0.0041250535927247235
# Dice:  0.9460948351025573
# T:  15
# Exec time per prediction = 0.156
# aleatoric:  0.02829557261895387
# epistemic:  0.004285754670592726
# Dice:  0.9462419707179075
# T:  20
# Exec time per prediction = 0.202
# aleatoric:  0.02828638327214871
# epistemic:  0.004351900549983841
# Dice:  0.9461128474473954
# T:  30
# Exec time per prediction = 0.301
# aleatoric:  0.028300842528231413
# epistemic:  0.004434436349809399
# Dice:  0.9460059678554518
# ------------------------------
# [[3.00000000e+00 5.00000000e+00 1.00000000e+01 1.50000000e+01
#   2.00000000e+01 3.00000000e+01]
#  [4.23948007e-02 6.28255150e-02 1.09279907e-01 1.56135705e-01
#   2.02282293e-01 3.00770514e-01]
#  [2.82986712e-02 2.82885990e-02 2.83085119e-02 2.82955726e-02
#   2.82863833e-02 2.83008425e-02]
#  [3.06023144e-03 3.67805666e-03 4.12505359e-03 4.28575467e-03
#   4.35190055e-03 4.43443635e-03]
#  [9.46061089e-01 9.46121853e-01 9.46094835e-01 9.46241971e-01
#   9.46112847e-01 9.46005968e-01]]
# ------------------------------

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(6,6), sharex=True)
# plot history for loss
ax.scatter(results[0],results[1])
ax.set_ylabel('Elapsed time per prediction')
ax.set_xlabel('Number of stochastics')
plt.savefig('./fig/elapsed_time_vs_feed_200')

# %%
# Case T = 5
num = len(X_test)
start = time.time()
list_alea = []
list_epis = []
for i in range(num):
    image = X_test[i]
    gt    = Y_test[i]
    prediction, aleatoric, epistemic, scores = utils.predict(model, image, gt, T=5)
    list_alea.append(aleatoric.reshape(-1))
    list_epis.append(epistemic.reshape(-1))

end = time.time()
print('Exec time per prediction = {:.3f}'.format((end-start)/num))
print('aleatoric: ', alea_mean)
print('epistemic: ', epis_mean)    
print('Dice: ', scores[0])
# Out:
# Exec time per prediction = 0.059
# aleatoric:  0.028300842528231413
# epistemic:  0.004434436349809399
# Dice:  0.9898003339767456

# %%
list_alea = np.hstack(list_alea)
list_epis = np.hstack(list_epis)

print('aleatoric mean: ', np.mean(list_alea))
print('epistemic mean: ', np.mean(list_epis))
# Out:
# aleatoric mean:  0.028303517
# epistemic mean:  0.003672632

# %% [markdown]
# # Epistemic vs Aleatoric

# %%
threshold = np.percentile(list_alea, 99)
alea_index = (list_alea > threshold)

# %%
plt.figure(figsize=(5,5))
data = np.vstack([list_alea[alea_index], list_epis[alea_index]]).T
ax = sns.kdeplot(data, shade = True, cmap = "gray", cbar=False)
ax.patch.set_facecolor('white')
ax.collections[0].set_alpha(0)
ax.set_xlabel('Aleatoric', fontsize = 15)
ax.set_ylabel('Epistemic', fontsize = 15)
ax.set_xlim(0.15, 0.25)
ax.set_ylim(0, 0.1)
plt.savefig('./fig/epis_vs_alea_2000')
# Out:
# /usr/local/lib/python3.5/dist-packages/seaborn/distributions.py:645: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %% [markdown]
# # Conditional expectation of epistemic

# %%
threshold_99 = np.percentile(list_alea, 99.)
threshold_995 = np.percentile(list_alea, 99.5)
threshold_999 = np.percentile(list_alea, 99.9)
threshold_9995 = np.percentile(list_alea, 99.95)
print(threshold_99, threshold_995, threshold_999, threshold_9995)
# alea_index = (list_alea > threshold)
# Out:
# 0.19313268840312947 0.20684921741485596 0.2272893213331703 0.23269513323903235

# %%
print('conditional expectation of epistemic')
print(
    np.mean([list_epis[i] for i in np.arange(len(list_alea)) if (list_alea[i] > 0.05) and (list_alea[i] < 0.1)]),
    np.mean([list_epis[i] for i in np.arange(len(list_alea)) if (list_alea[i] > 0.1) and (list_alea[i] < 0.15)]),
    np.mean([list_epis[i] for i in np.arange(len(list_alea)) if (list_alea[i] > 0.15) and (list_alea[i] < 0.2)]),
    np.mean([list_epis[i] for i in np.arange(len(list_alea)) if (list_alea[i] > 0.2) and (list_alea[i] < 0.25)])
    )
# Out:
# conditional expectation of epistemic
# 0.011590821 0.037914086 0.044452664 0.0260144

# %%
96*96*2000/(10 ** 6)
# Out:
# 18.432
